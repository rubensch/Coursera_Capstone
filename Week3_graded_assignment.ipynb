# %% [markdown]
# # First Install the necessary Wikipedia package
# ## Then import all libraries and bind to an alias

# %%
# !conda install -c conda-forge wikipedia --yes 
import wikipedia as wp
# Out:
# Collecting package metadata: done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::anaconda==5.3.1=py37_0
#   - defaults/linux-64::astropy==3.0.4=py37h14c3975_0
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::bokeh==0.13.0=py37_0
#   - defaults/linux-64::bottleneck==1.2.1=py37h035aef0_1
#   - defaults/linux-64::dask==0.19.1=py37_0
#   - defaults/linux-64::datashape==0.5.4=py37_1
#   - defaults/linux-64::mkl-service==1.1.2=py37h90e4bf4_5
#   - defaults/linux-64::numba==0.39.0=py37h04863e7_0
#   - defaults/linux-64::numexpr==2.6.8=py37hd89afb7_0
#   - defaults/linux-64::odo==0.5.1=py37_0
#   - defaults/linux-64::pytables==3.4.4=py37ha205bf6_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py37_0
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py37_0
#   - defaults/linux-64::pywavelets==1.0.0=py37hdd07704_0
#   - defaults/linux-64::scikit-image==0.14.0=py37hf484d3e_1
# done
#
# # All requested packages already installed.

# %%
import pandas as pd
import requests as req
import numpy as np

# %% [markdown]
# # Second we will download the needed Wiki page from Wikipedia.org

# %%
url_address=wp.page(title = 'List of postal codes of Canada: M').url
wiki_htmlbody=req.get(url_address).text

# %% [markdown]
# # Now scrape the html body, find the embedded table, and push it to a Pandas Dataframe

# %%
soup=wp.BeautifulSoup(wiki_htmlbody,'lxml')
postalcode_table=soup.find('table',{'class':'wikitable sortable'})
ths=postalcode_table.find_all('th')    
headings = [th.text.strip() for th in ths]

lines=[]
with open('postalcodes.txt', 'w') as fo:
    for tr in postalcode_table.find_all('tr'):        
        tds = tr.find_all('td')
        if not tds:
            continue
        postcode, borough, neighborhood = [td.text.strip() for td in tds[:3]]
        # Wikipedia does something funny with country names containing
        # accented characters: extract the correct string form.

        lines.append([postcode, borough, neighborhood])
    print(lines)



tables = pd.read_html(url_address, header=0,
                      keep_default_na=False)

headings = ['Postcode', 'Borough', 'Neighbourhood']
for table in tables:
    current_headings = table.columns.values[:3]
    if len(current_headings) != len(headings):
        continue
    if all(current_headings == headings):
        break
# Out:
# [['M1A', 'Not assigned', 'Not assigned'], ['M2A', 'Not assigned', 'Not assigned'], ['M3A', 'North York', 'Parkwoods'], ['M4A', 'North York', 'Victoria Village'], ['M5A', 'Downtown Toronto', 'Harbourfront'], ['M5A', 'Downtown Toronto', 'Regent Park'], ['M6A', 'North York', 'Lawrence Heights'], ['M6A', 'North York', 'Lawrence Manor'], ['M7A', "Queen's Park", 'Not assigned'], ['M8A', 'Not assigned', 'Not assigned'], ['M9A', 'Etobicoke', 'Islington Avenue'], ['M1B', 'Scarborough', 'Rouge'], ['M1B', 'Scarborough', 'Malvern'], ['M2B', 'Not assigned', 'Not assigned'], ['M3B', 'North York', 'Don Mills North'], ['M4B', 'East York', 'Woodbine Gardens'], ['M4B', 'East York', 'Parkview Hill'], ['M5B', 'Downtown Toronto', 'Ryerson'], ['M5B', 'Downtown Toronto', 'Garden District'], ['M6B', 'North York', 'Glencairn'], ['M7B', 'Not assigned', 'Not assigned'], ['M8B', 'Not assigned', 'Not assigned'], ['M9B', 'Etobicoke', 'Cloverdale'], ['M9B', 'Etobicoke', 'Islington'], ['M9B', 'Etobicoke', 'Martin Grove'], ['M9B', 'Etobicoke', 'Princess Gardens'], ['M9B', 'Etobicoke', 'West Deane Park'], ['M1C', 'Scarborough', 'Highland Creek'], ['M1C', 'Scarborough', 'Rouge Hill'], ['M1C', 'Scarborough', 'Port Union'], ['M2C', 'Not assigned', 'Not assigned'], ['M3C', 'North York', 'Flemingdon Park'], ['M3C', 'North York', 'Don Mills South'], ['M4C', 'East York', 'Woodbine Heights'], ['M5C', 'Downtown Toronto', 'St. James Town'], ['M6C', 'York', 'Humewood-Cedarvale'], ['M7C', 'Not assigned', 'Not assigned'], ['M8C', 'Not assigned', 'Not assigned'], ['M9C', 'Etobicoke', 'Bloordale Gardens'], ['M9C', 'Etobicoke', 'Eringate'], ['M9C', 'Etobicoke', 'Markland Wood'], ['M9C', 'Etobicoke', 'Old Burnhamthorpe'], ['M1E', 'Scarborough', 'Guildwood'], ['M1E', 'Scarborough', 'Morningside'], ['M1E', 'Scarborough', 'West Hill'], ['M2E', 'Not assigned', 'Not assigned'], ['M3E', 'Not assigned', 'Not assigned'], ['M4E', 'East Toronto', 'The Beaches'], ['M5E', 'Downtown Toronto', 'Berczy Park'], ['M6E', 'York', 'Caledonia-Fairbanks'], ['M7E', 'Not assigned', 'Not assigned'], ['M8E', 'Not assigned', 'Not assigned'], ['M9E', 'Not assigned', 'Not assigned'], ['M1G', 'Scarborough', 'Woburn'], ['M2G', 'Not assigned', 'Not assigned'], ['M3G', 'Not assigned', 'Not assigned'], ['M4G', 'East York', 'Leaside'], ['M5G', 'Downtown Toronto', 'Central Bay Street'], ['M6G', 'Downtown Toronto', 'Christie'], ['M7G', 'Not assigned', 'Not assigned'], ['M8G', 'Not assigned', 'Not assigned'], ['M9G', 'Not assigned', 'Not assigned'], ['M1H', 'Scarborough', 'Cedarbrae'], ['M2H', 'North York', 'Hillcrest Village'], ['M3H', 'North York', 'Bathurst Manor'], ['M3H', 'North York', 'Downsview North'], ['M3H', 'North York', 'Wilson Heights'], ['M4H', 'East York', 'Thorncliffe Park'], ['M5H', 'Downtown Toronto', 'Adelaide'], ['M5H', 'Downtown Toronto', 'King'], ['M5H', 'Downtown Toronto', 'Richmond'], ['M6H', 'West Toronto', 'Dovercourt Village'], ['M6H', 'West Toronto', 'Dufferin'], ['M7H', 'Not assigned', 'Not assigned'], ['M8H', 'Not assigned', 'Not assigned'], ['M9H', 'Not assigned', 'Not assigned'], ['M1J', 'Scarborough', 'Scarborough Village'], ['M2J', 'North York', 'Fairview'], ['M2J', 'North York', 'Henry Farm'], ['M2J', 'North York', 'Oriole'], ['M3J', 'North York', 'Northwood Park'], ['M3J', 'North York', 'York University'], ['M4J', 'East York', 'East Toronto'], ['M5J', 'Downtown Toronto', 'Harbourfront East'], ['M5J', 'Downtown Toronto', 'Toronto Islands'], ['M5J', 'Downtown Toronto', 'Union Station'], ['M6J', 'West Toronto', 'Little Portugal'], ['M6J', 'West Toronto', 'Trinity'], ['M7J', 'Not assigned', 'Not assigned'], ['M8J', 'Not assigned', 'Not assigned'], ['M9J', 'Not assigned', 'Not assigned'], ['M1K', 'Scarborough', 'East Birchmount Park'], ['M1K', 'Scarborough', 'Ionview'], ['M1K', 'Scarborough', 'Kennedy Park'], ['M2K', 'North York', 'Bayview Village'], ['M3K', 'North York', 'CFB Toronto'], ['M3K', 'North York', 'Downsview East'], ['M4K', 'East Toronto', 'The Danforth West'], ['M4K', 'E ...

# %% [markdown]
# # Now we rename the Postcode column, to PostalCode, as shown in the required example

# %%
table.rename(index=str, columns={"Postcode": "PostalCode"},inplace=True)

# %% [markdown]
# # Drop all records with a 'Not Assigned' value for column Neighbourhood

# %%
filtered_table=table.loc[table['Borough'] != "Not assigned"].reset_index()
filtered_table
# Out:
#     index PostalCode           Borough  \
# 0       2        M3A        North York
# 1       3        M4A        North York
# 2       4        M5A  Downtown Toronto
# 3       5        M5A  Downtown Toronto
# 4       6        M6A        North York
# 5       7        M6A        North York
# 6       8        M7A      Queen's Park
# 7      10        M9A         Etobicoke
# 8      11        M1B       Scarborough
# 9      12        M1B       Scarborough
# 10     14        M3B        North York
# 11     15        M4B         East York
# 12     16        M4B         East York
# 13     17        M5B  Downtown Toronto
# 14     18        M5B  Downtown Toronto
# 15     19        M6B        North York
# 16     22        M9B         Etobicoke
# 17     23        M9B         Etobicoke
# 18     24        M9B         Etobicoke
# 19     25        M9B         Etobicoke
# 20     26        M9B         Etobicoke
# 21     27        M1C       Scarborough
# 22     28        M1C       Scarborough
# 23     29        M1C       Scarborough
# 24     31        M3C        North York
# 25     32        M3C        North York
# 26     33        M4C         East York
# 27     34        M5C  Downtown Toronto
# 28     35        M6C              York
# 29     38        M9C         Etobicoke
# ..    ...        ...               ...
# 181   235        M9V         Etobicoke
# 182   236        M1W       Scarborough
# 183   239        M4W  Downtown Toronto
# 184   240        M5W  Downtown Toronto
# 185   243        M8W         Etobicoke
# 186   244        M8W         Etobicoke
# 187   245        M9W         Etobicoke
# 188   246        M1X       Scarborough
# 189   249        M4X  Downtown Toronto
# 190   250        M4X  Downtown Toronto
# 191   251        M5X  Downtown Toronto
# 192   252        M5X  Downtown Toronto
# 193   255        M8X         Etobicoke
# 194   256        M8X         Etobicoke
# 195   257        M8X         Etobicoke
# 196   262        M4Y  Downtown Toronto
# 197   265        M7Y      East Toronto
# 198   266        M8Y         Etobicoke
# 199   267        M8Y         Etobicoke
# 200   268        M8Y         Etobicoke
# 201   269        M8Y         Etobicoke
# 202   270        M8Y         Etobicoke
# 203   271        M8Y         Etobicoke
# 204   272        M8Y         Etobicoke
# 205   273        M8Y         Etobicoke
# 206   282        M8Z         Etobicoke
# 207   283        M8Z         Etobicoke
# 208   284        M8Z         Etobicoke
# 209   285        M8Z         Etobicoke
# 210   286        M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                                          Regent Park
# 4                                     Lawrence Heights
# 5                                       Lawrence Manor
# 6                                         Not assigned
# 7                                     Islington Avenue
# 8                                                Rouge
# 9                                              Malvern
# 10                                     Don Mills North
# 11                                    Woodbine Gardens
# 12                                       Parkview Hill
# 13                                             Ryerson
# 14                                     Garden District
# 15                                           Glencairn
# 16                                          Cloverdale
# 17                                           Islington
# 18                                        Martin Grove
# 19                                    Princess Gardens
# 20                                     West Deane Park
# 21                                      Highland Creek
# 22                                          Rouge Hill
# 23                                          Port Union
# 24                                     Flemingdon Park
# 25                                     Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                                   Bloordale Gardens
# ..                                                 ...
# 181                                        Thistletown
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                                          Alderwood
# 186                                        Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                                        Cabbagetown
# 190                                     St. James Town
# 191                               First Canadian Place
# 192                                   Underground city
# 193                                       The Kingsway
# 194                                    Montgomery Road
# 195                                     Old Mill North
# 196                               Church and Wellesley
# 197  Business Reply Mail Processing Centre 969 Eastern
# 198                                         Humber Bay
# 199                                   King's Mill Park
# 200                           Kingsway Park South East
# 201                                          Mimico NE
# 202                                     Old Mill South
# 203                                 The Queensway East
# 204                              Royal York South East
# 205                                           Sunnylea
# 206                           Kingsway Park South West
# 207                                          Mimico NW
# 208                                 The Queensway West
# 209                              Royal York South West
# 210                                     South of Bloor
#
# [211 rows x 4 columns]

# %% [markdown]
# # Drop the entire column 'index'

# %%
df_hoods=filtered_table.drop(['index'],axis=1)
df_hoods
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M5A  Downtown Toronto
# 4          M6A        North York
# 5          M6A        North York
# 6          M7A      Queen's Park
# 7          M9A         Etobicoke
# 8          M1B       Scarborough
# 9          M1B       Scarborough
# 10         M3B        North York
# 11         M4B         East York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M5B  Downtown Toronto
# 15         M6B        North York
# 16         M9B         Etobicoke
# 17         M9B         Etobicoke
# 18         M9B         Etobicoke
# 19         M9B         Etobicoke
# 20         M9B         Etobicoke
# 21         M1C       Scarborough
# 22         M1C       Scarborough
# 23         M1C       Scarborough
# 24         M3C        North York
# 25         M3C        North York
# 26         M4C         East York
# 27         M5C  Downtown Toronto
# 28         M6C              York
# 29         M9C         Etobicoke
# ..         ...               ...
# 181        M9V         Etobicoke
# 182        M1W       Scarborough
# 183        M4W  Downtown Toronto
# 184        M5W  Downtown Toronto
# 185        M8W         Etobicoke
# 186        M8W         Etobicoke
# 187        M9W         Etobicoke
# 188        M1X       Scarborough
# 189        M4X  Downtown Toronto
# 190        M4X  Downtown Toronto
# 191        M5X  Downtown Toronto
# 192        M5X  Downtown Toronto
# 193        M8X         Etobicoke
# 194        M8X         Etobicoke
# 195        M8X         Etobicoke
# 196        M4Y  Downtown Toronto
# 197        M7Y      East Toronto
# 198        M8Y         Etobicoke
# 199        M8Y         Etobicoke
# 200        M8Y         Etobicoke
# 201        M8Y         Etobicoke
# 202        M8Y         Etobicoke
# 203        M8Y         Etobicoke
# 204        M8Y         Etobicoke
# 205        M8Y         Etobicoke
# 206        M8Z         Etobicoke
# 207        M8Z         Etobicoke
# 208        M8Z         Etobicoke
# 209        M8Z         Etobicoke
# 210        M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                                          Regent Park
# 4                                     Lawrence Heights
# 5                                       Lawrence Manor
# 6                                         Not assigned
# 7                                     Islington Avenue
# 8                                                Rouge
# 9                                              Malvern
# 10                                     Don Mills North
# 11                                    Woodbine Gardens
# 12                                       Parkview Hill
# 13                                             Ryerson
# 14                                     Garden District
# 15                                           Glencairn
# 16                                          Cloverdale
# 17                                           Islington
# 18                                        Martin Grove
# 19                                    Princess Gardens
# 20                                     West Deane Park
# 21                                      Highland Creek
# 22                                          Rouge Hill
# 23                                          Port Union
# 24                                     Flemingdon Park
# 25                                     Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                                   Bloordale Gardens
# ..                                                 ...
# 181                                        Thistletown
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                                          Alderwood
# 186                                        Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                                        Cabbagetown
# 190                                     St. James Town
# 191                               First Canadian Place
# 192                                   Underground city
# 193                                       The Kingsway
# 194                                    Montgomery Road
# 195                                     Old Mill North
# 196                               Church and Wellesley
# 197  Business Reply Mail Processing Centre 969 Eastern
# 198                                         Humber Bay
# 199                                   King's Mill Park
# 200                           Kingsway Park South East
# 201                                          Mimico NE
# 202                                     Old Mill South
# 203                                 The Queensway East
# 204                              Royal York South East
# 205                                           Sunnylea
# 206                           Kingsway Park South West
# 207                                          Mimico NW
# 208                                 The Queensway West
# 209                              Royal York South West
# 210                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
import numpy as np
df_hoods['Neighbourhood'] = np.where(df_hoods['Neighbourhood'] == 'Not assigned', df_hoods['Borough'],df_hoods['Neighbourhood'])

df_hoods
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M5A  Downtown Toronto
# 4          M6A        North York
# 5          M6A        North York
# 6          M7A      Queen's Park
# 7          M9A         Etobicoke
# 8          M1B       Scarborough
# 9          M1B       Scarborough
# 10         M3B        North York
# 11         M4B         East York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M5B  Downtown Toronto
# 15         M6B        North York
# 16         M9B         Etobicoke
# 17         M9B         Etobicoke
# 18         M9B         Etobicoke
# 19         M9B         Etobicoke
# 20         M9B         Etobicoke
# 21         M1C       Scarborough
# 22         M1C       Scarborough
# 23         M1C       Scarborough
# 24         M3C        North York
# 25         M3C        North York
# 26         M4C         East York
# 27         M5C  Downtown Toronto
# 28         M6C              York
# 29         M9C         Etobicoke
# ..         ...               ...
# 181        M9V         Etobicoke
# 182        M1W       Scarborough
# 183        M4W  Downtown Toronto
# 184        M5W  Downtown Toronto
# 185        M8W         Etobicoke
# 186        M8W         Etobicoke
# 187        M9W         Etobicoke
# 188        M1X       Scarborough
# 189        M4X  Downtown Toronto
# 190        M4X  Downtown Toronto
# 191        M5X  Downtown Toronto
# 192        M5X  Downtown Toronto
# 193        M8X         Etobicoke
# 194        M8X         Etobicoke
# 195        M8X         Etobicoke
# 196        M4Y  Downtown Toronto
# 197        M7Y      East Toronto
# 198        M8Y         Etobicoke
# 199        M8Y         Etobicoke
# 200        M8Y         Etobicoke
# 201        M8Y         Etobicoke
# 202        M8Y         Etobicoke
# 203        M8Y         Etobicoke
# 204        M8Y         Etobicoke
# 205        M8Y         Etobicoke
# 206        M8Z         Etobicoke
# 207        M8Z         Etobicoke
# 208        M8Z         Etobicoke
# 209        M8Z         Etobicoke
# 210        M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                                          Regent Park
# 4                                     Lawrence Heights
# 5                                       Lawrence Manor
# 6                                         Queen's Park
# 7                                     Islington Avenue
# 8                                                Rouge
# 9                                              Malvern
# 10                                     Don Mills North
# 11                                    Woodbine Gardens
# 12                                       Parkview Hill
# 13                                             Ryerson
# 14                                     Garden District
# 15                                           Glencairn
# 16                                          Cloverdale
# 17                                           Islington
# 18                                        Martin Grove
# 19                                    Princess Gardens
# 20                                     West Deane Park
# 21                                      Highland Creek
# 22                                          Rouge Hill
# 23                                          Port Union
# 24                                     Flemingdon Park
# 25                                     Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                                   Bloordale Gardens
# ..                                                 ...
# 181                                        Thistletown
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                                          Alderwood
# 186                                        Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                                        Cabbagetown
# 190                                     St. James Town
# 191                               First Canadian Place
# 192                                   Underground city
# 193                                       The Kingsway
# 194                                    Montgomery Road
# 195                                     Old Mill North
# 196                               Church and Wellesley
# 197  Business Reply Mail Processing Centre 969 Eastern
# 198                                         Humber Bay
# 199                                   King's Mill Park
# 200                           Kingsway Park South East
# 201                                          Mimico NE
# 202                                     Old Mill South
# 203                                 The Queensway East
# 204                              Royal York South East
# 205                                           Sunnylea
# 206                           Kingsway Park South West
# 207                                          Mimico NW
# 208                                 The Queensway West
# 209                              Royal York South West
# 210                                     South of Bloor
#
# [211 rows x 3 columns]

# %% [markdown]
# # Group by PostalCode, and join all value in column where we find duplicate values

# %%
df_final=df_hoods.groupby('PostalCode').agg(lambda x : ', '.join(set(x))).reset_index()

# %% [markdown]
# # The sorting of the Dataframe is different from the example in the instructions, but the content is identical
# # Every PostalCode with more than 1 Neighbourhood has concatenated values using comma (', )' and Boroughs with 'Not assigned' values for Neighbourhood, have its Borough name.

# %%
df_final
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                       Malvern, Rouge
# 1               Highland Creek, Rouge Hill, Port Union
# 2                    Morningside, Guildwood, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          Ionview, Kennedy Park, East Birchmount Park
# 7                      Golden Mile, Clairlea, Oakridge
# 8      Cliffside, Scarborough Village West, Cliffcrest
# 9                          Cliffside West, Birch Cliff
# 10   Scarborough Town Centre, Wexford Heights, Dors...
# 11                                   Wexford, Maryvale
# 12                                           Agincourt
# 13             Sullivan, Clarks Corners, Tam O'Shanter
# 14   Agincourt North, Steeles East, L'Amoreaux East...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Fairview, Oriole, Henry Farm
# 19                                     Bayview Village
# 20                            Silver Hills, York Mills
# 21                             Willowdale, Newtonbrook
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Don Mills South, Flemingdon Park
# 28     Downsview North, Wilson Heights, Bathurst Manor
# 29                     Northwood Park, York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                        Dovercourt Village, Dufferin
# 77                            Little Portugal, Trinity
# 78        Exhibition Place, Parkdale Village, Brockton
# 79                  Upwood Park, North Park, Downsview
# 80      Silverthorn, Mount Dennis, Keelesdale, Del Ray
# 81                       The Junction North, Runnymede
# 82                       High Park, The Junction South
# 83                              Parkdale, Roncesvalles
# 84                                  Swansea, Runnymede
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88        Mimico South, New Toronto, Humber Bay Shores
# 89                              Alderwood, Long Branch
# 90       The Kingsway, Montgomery Road, Old Mill North
# 91   Sunnylea, Kingsway Park South East, Mimico NE,...
# 92   Kingsway Park South West, The Queensway West, ...
# 93                                    Islington Avenue
# 94   Princess Gardens, West Deane Park, Martin Grov...
# 95   Markland Wood, Old Burnhamthorpe, Bloordale Ga...
# 96                                       Humber Summit
# 97                                    Emery, Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100  Richview Gardens, Kingsview Village, St. Phill...
# 101  Mount Olive, South Steeles, Thistletown, Silve...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %%
df_final.shape
# Out:
# (103, 3)

# %%
coordinates_df=pd.read_csv('https://cocl.us/Geospatial_data')
coordinates_df
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# 24          M2R  43.782736 -79.442259
# 25          M3A  43.753259 -79.329656
# 26          M3B  43.745906 -79.352188
# 27          M3C  43.725900 -79.340923
# 28          M3H  43.754328 -79.442259
# 29          M3J  43.767980 -79.487262
# ..          ...        ...        ...
# 73          M6C  43.693781 -79.428191
# 74          M6E  43.689026 -79.453512
# 75          M6G  43.669542 -79.422564
# 76          M6H  43.669005 -79.442259
# 77          M6J  43.647927 -79.419750
# 78          M6K  43.636847 -79.428191
# 79          M6L  43.713756 -79.490074
# 80          M6M  43.691116 -79.476013
# 81          M6N  43.673185 -79.487262
# 82          M6P  43.661608 -79.464763
# 83          M6R  43.648960 -79.456325
# 84          M6S  43.651571 -79.484450
# 85          M7A  43.662301 -79.389494
# 86          M7R  43.636966 -79.615819
# 87          M7Y  43.662744 -79.321558
# 88          M8V  43.605647 -79.501321
# 89          M8W  43.602414 -79.543484
# 90          M8X  43.653654 -79.506944
# 91          M8Y  43.636258 -79.498509
# 92          M8Z  43.628841 -79.520999
# 93          M9A  43.667856 -79.532242
# 94          M9B  43.650943 -79.554724
# 95          M9C  43.643515 -79.577201
# 96          M9L  43.756303 -79.565963
# 97          M9M  43.724766 -79.532242
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
def get_lat_long_by_postalcode(postalcode):
    lat=coordinates_df.loc[coordinates_df['Postal Code'] == postalcode].Latitude.item()
    long=coordinates_df.loc[coordinates_df['Postal Code'] == postalcode].Longitude.item()    
    return lat,long

# %%
##lat,long=get_lat_long_by_postalcode('M5G',read_csv)

##df_final['Latitude'], df_final['Longitude'] = zip(*df_final['PostalCode'].apply(get_lat_long_by_postalcode))
df_final['Latitude'] = None
df_final['Longitude'] = None

for i in range(0,len(df_final)):
    df_final['Latitude'][i],df_final['Longitude'][i]=get_lat_long_by_postalcode(df_final.iloc[i]['PostalCode'])

# %%
df_final
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                          Neighbourhood Latitude Longitude
# 0                                       Malvern, Rouge  43.8067  -79.1944
# 1               Highland Creek, Rouge Hill, Port Union  43.7845  -79.1605
# 2                    Morningside, Guildwood, West Hill  43.7636  -79.1887
# 3                                               Woburn   43.771  -79.2169
# 4                                            Cedarbrae  43.7731  -79.2395
# 5                                  Scarborough Village  43.7447  -79.2395
# 6          Ionview, Kennedy Park, East Birchmount Park  43.7279   -79.262
# 7                      Golden Mile, Clairlea, Oakridge  43.7111  -79.2846
# 8      Cliffside, Scarborough Village West, Cliffcrest  43.7163  -79.2395
# 9                          Cliffside West, Birch Cliff  43.6927  -79.2648
# 10   Scarborough Town Centre, Wexford Heights, Dors...  43.7574  -79.2733
# 11                                   Wexford, Maryvale  43.7501  -79.2958
# 12                                           Agincourt  43.7942   -79.262
# 13             Sullivan, Clarks Corners, Tam O'Shanter  43.7816  -79.3043
# 14   Agincourt North, Steeles East, L'Amoreaux East...  43.8153  -79.2846
# 15                                     L'Amoreaux West  43.7995  -79.3184
# 16                                         Upper Rouge  43.8361  -79.2056
# 17                                   Hillcrest Village  43.8038  -79.3635
# 18                        Fairview, Oriole, Henry Farm  43.7785  -79.3466
# 19                                     Bayview Village  43.7869   -79.386
# 20                            Silver Hills, York Mills  43.7575  -79.3747
# 21                             Willowdale, Newtonbrook  43.7891  -79.4085
# 22                                    Willowdale South  43.7701  -79.4085
# 23                                     York Mills West  43.7528     -79.4
# 24                                     Willowdale West  43.7827  -79.4423
# 25                                           Parkwoods  43.7533  -79.3297
# 26                                     Don Mills North  43.7459  -79.3522
# 27                    Don Mills South, Flemingdon Park  43.7259  -79.3409
# 28     Downsview North, Wilson Heights, Bathurst Manor  43.7543  -79.4423
# 29                     Northwood Park, York University   43.768  -79.4873
# ..                                                 ...      ...       ...
# 73                                  Humewood-Cedarvale  43.6938  -79.4282
# 74                                 Caledonia-Fairbanks   43.689  -79.4535
# 75                                            Christie  43.6695  -79.4226
# 76                        Dovercourt Village, Dufferin   43.669  -79.4423
# 77                            Little Portugal, Trinity  43.6479  -79.4197
# 78        Exhibition Place, Parkdale Village, Brockton  43.6368  -79.4282
# 79                  Upwood Park, North Park, Downsview  43.7138  -79.4901
# 80      Silverthorn, Mount Dennis, Keelesdale, Del Ray  43.6911   -79.476
# 81                       The Junction North, Runnymede  43.6732  -79.4873
# 82                       High Park, The Junction South  43.6616  -79.4648
# 83                              Parkdale, Roncesvalles   43.649  -79.4563
# 84                                  Swansea, Runnymede  43.6516  -79.4844
# 85                                        Queen's Park  43.6623  -79.3895
# 86               Canada Post Gateway Processing Centre   43.637  -79.6158
# 87   Business Reply Mail Processing Centre 969 Eastern  43.6627  -79.3216
# 88        Mimico South, New Toronto, Humber Bay Shores  43.6056  -79.5013
# 89                              Alderwood, Long Branch  43.6024  -79.5435
# 90       The Kingsway, Montgomery Road, Old Mill North  43.6537  -79.5069
# 91   Sunnylea, Kingsway Park South East, Mimico NE,...  43.6363  -79.4985
# 92   Kingsway Park South West, The Queensway West, ...  43.6288   -79.521
# 93                                    Islington Avenue  43.6679  -79.5322
# 94   Princess Gardens, West Deane Park, Martin Grov...  43.6509  -79.5547
# 95   Markland Wood, Old Burnhamthorpe, Bloordale Ga...  43.6435  -79.5772
# 96                                       Humber Summit  43.7563   -79.566
# 97                                    Emery, Humberlea  43.7248  -79.5322
# 98                                              Weston  43.7069  -79.5182
# 99                                           Westmount  43.6963  -79.5322
# 100  Richview Gardens, Kingsview Village, St. Phill...  43.6889  -79.5547
# 101  Mount Olive, South Steeles, Thistletown, Silve...  43.7394  -79.5884
# 102                                          Northwest  43.7067  -79.5941
#
# [103 rows x 5 columns]
